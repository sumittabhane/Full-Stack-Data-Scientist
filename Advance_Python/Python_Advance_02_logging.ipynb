# %%
import logging

# %%
logging.basicConfig(filename='logging.log',level=logging.info)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 logging.basicConfig(filename='logging.log',level=logging.info)
#
# File ~\anaconda3\Lib\logging\__init__.py:2069, in basicConfig(**kwargs)
#    2067 level = kwargs.pop("level", None)
#    2068 if level is not None:
# -> 2069     root.setLevel(level)
#    2070 if kwargs:
#    2071     keys = ', '.join(kwargs.keys())
#
# File ~\anaconda3\Lib\logging\__init__.py:1464, in Logger.setLevel(self, level)
#    1460 def setLevel(self, level):
#    1461     """
#    1462     Set the logging level of this logger.  level must be an int or a str.
#    1463     """
# -> 1464     self.level = _checkLevel(level)
#    1465     self.manager._clear_cache()
#
# File ~\anaconda3\Lib\logging\__init__.py:210, in _checkLevel(level)
#     208     rv = _nameToLevel[level]
#     209 else:
# ...

# %%
logging.info('This is my log')
logging.error('This is my error')

# %%
logging.shutdown()

# %%
logging.basicConfig(filename='C:/Users/sumit/Internmeets data science/Advance Python/function.log', level=logging.DEBUG ,format='%(astime)s %(levelname)s %(message)s',force=True)

# %%
def test1():
    logging.debug('This is my debug log')
    logging.info('This is my info log')
    logging.warning('This is my wrning log')
    logging.error('This is my error log')
    return 100

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
test1()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Users\sumit\anaconda3\Lib\logging\__init__.py", line 449, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sumit\anaconda3\Lib\logging\__init__.py", line 445, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'astime'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\sumit\anaconda3\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sumit\anaconda3\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "C:\Users\sumit\anaconda3\Lib\logging\__init__.py", line 690, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
pwd()
# Out:
# 'C:\\Users\\sumit\\Internmeets data science\\Advance Python'

# %%
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 8EB0-A4CB
#
#  Directory of C:\Users\sumit\Internmeets data science\Advance Python
#
# 27-06-2024  16:04    <DIR>          .
# 26-06-2024  16:14    <DIR>          ..
# 27-06-2024  15:52    <DIR>          .ipynb_checkpoints
# 27-06-2024  16:04               374 logging.log
# 26-06-2024  16:30             7,001 Python_Advance_01_try_catch.ipynb
# 27-06-2024  16:04             6,093 Python_Advance_02_logging.ipynb
#                3 File(s)         13,468 bytes
#                3 Dir(s)  55,704,608,768 bytes free
